# %%
import matplotlib.font_manager as fm

# 列出所有可用字体
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(font)
# Out:
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/UbuntuMono-R.ttf
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/Ubuntu-MI.ttf
# /mnt/afs/yaotiankuo/.fonts/chartfonts/华文仿宋.ttf
# /mnt/afs/yaotiankuo/.fonts/chartfonts/华文隶体.TTF
# /mnt/afs/yaotiankuo/.local/share/fonts/HarmonyOS Sans/HarmonyOS_Sans_Naskh_Arabic/HarmonyOS_Sans_Naskh_Arabic_Light.ttf
# /mnt/afs/yaotiankuo/.local/share/fonts/HarmonyOS Sans/HarmonyOS_Sans_Condensed_Italic/HarmonyOS_Sans_Condensed_Black_Italic.ttf
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/SourceCodePro-SemiboldIt.ttf
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/Ubuntu-B.ttf
# /mnt/afs/yaotiankuo/.local/share/fonts/HarmonyOS Sans/HarmonyOS_Sans_Condensed/HarmonyOS_Sans_Condensed_Thin.ttf
# /mnt/afs/yaotiankuo/.fonts/DejaVuSans.ttf
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/Inconsolata-Regular.ttf
# /mnt/afs/yaotiankuo/.conda/envs/chart/fonts/SourceCodePro-Bold.ttf
# /mnt/afs/yaotiankuo/.fonts/chartfonts/noto/NotoSerifCJK-Regular.ttc
# ...
